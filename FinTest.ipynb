# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('finalproject0.xlsx')

# %%
df.head()
# Out:
#    label  類別                      標題  \
# 0      1  娛樂        田馥甄簽約何樂宣佈專巡送花籃力挺
# 1      1  娛樂   梁靜茹新作好慘睽違年才回歸坦言對公司很抱歉
# 2      1  娛樂  追星追起來登坂廣臣自告奮勇來台宣傳舉辦前夜祭
# 3      1  娛樂   再會平成回顧輝煌歲月宇多田光締造的日音奇蹟
# 4      1  娛樂    嘻哈狂粉注意紐約傳奇與世紀同台演唱會回顧
#
#                                           標題分詞和去除停用詞
# 0   ['田馥甄', '簽約', '何樂宣', '佈', '專巡', '送', '花籃', '力挺']
# 1  ['梁靜茹', '新', '作好', '慘睽', '違年', '回歸', '坦言', '公司...
# 2  ['追星', '追起', '登坂廣臣', '自告', '奮勇來', '台', '宣傳', '...
# 3  ['再會', '平成', '回顧輝煌', '歲', '月', '宇多田光', '締造', '...
# 4  ['嘻哈狂', '粉', '注意', '紐約', '傳奇', '世紀', '同台', '演唱...

# %%
df.類別.unique()
# Out:
# array(['娛樂', '生活', '社會', '政治', '財經', '國際', '體育'], dtype=object)

# %%
df1 = df[ ['label', '標題'] ]

# %%
df1['words'] = df1['標題'].apply(lambda x: re.findall('[\x80-\xff]{3}|[\w\W]', x))
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
import re

# %%
df1.head()
# Out:
#    label                      標題  \
# 0      1        田馥甄簽約何樂宣佈專巡送花籃力挺
# 1      1   梁靜茹新作好慘睽違年才回歸坦言對公司很抱歉
# 2      1  追星追起來登坂廣臣自告奮勇來台宣傳舉辦前夜祭
# 3      1   再會平成回顧輝煌歲月宇多田光締造的日音奇蹟
# 4      1    嘻哈狂粉注意紐約傳奇與世紀同台演唱會回顧
#
#                                                words
# 0   [田, 馥, 甄, 簽, 約, 何, 樂, 宣, 佈, 專, 巡, 送, 花, 籃, 力, 挺]
# 1  [梁, 靜, 茹, 新, 作, 好, 慘, 睽, 違, 年, 才, 回, 歸, 坦, 言, ...
# 2  [追, 星, 追, 起, 來, 登, 坂, 廣, 臣, 自, 告, 奮, 勇, 來, 台, ...
# 3  [再, 會, 平, 成, 回, 顧, 輝, 煌, 歲, 月, 宇, 多, 田, 光, 締, ...
# 4  [嘻, 哈, 狂, 粉, 注, 意, 紐, 約, 傳, 奇, 與, 世, 紀, 同, 台, ...

# %%
all_words = []
for w in df1['words']:
    all_words.extend(w)
word_dict = pd.DataFrame(pd.Series(all_words).value_counts())
word_dict['id'] = list(range(1, len(word_dict)+1))

# %%
word_dict
# Out:
#        0    id
# 國   7351     1
# 大   6489     2
# 人   6400     3
# 台   6385     4
# 美   6173     5
# 中   4728     6
# 年   4311     7
# 新   4136     8
# 不   3966     9
# 會   3668    10
# 一   3514    11
# 日   3502    12
# 的   3397    13
# 金   3025    14
# 出   2784    15
# 英   2740    16
# 開   2692    17
# 民   2629    18
# 全   2339    19
# 女   2326    20
# 法   2326    21
# 最   2229    22
# 家   2203    23
# 上   2182    24
# 生   2171    25
# 高   2162    26
# 小   2159    27
# 球   2151    28
# 成   2080    29
# 選   2016    30
# ..   ...   ...
# 厂      1  4616
# 徉      1  4617
# 蝓      1  4618
# 窕      1  4619
# 黔      1  4620
# 瑢      1  4621
# 涮      1  4622
# 詼      1  4623
# 扉      1  4624
# 跩      1  4625
# 噌      1  4626
# 泗      1  4627
# 湘      1  4628
# 灝      1  4629
# 曛      1  4630
# 蛟      1  4631
# 气      1  4632
# 諭      1  4633
# 譬      1  4634
# 嚥      1  4635
# 哏      1  4636
# 圃      1  4637
# 湃      1  4638
# 羲      1  4639
# 彪      1  4640
# 倚      1  4641
# 泂      1  4642
# 芃      1  4643
# 磺      1  4644
# 资      1  4645
#
# [4645 rows x 2 columns]

# %%
df1['wordidlist'] = df1['words'].apply(lambda x: list(word_dict['id'][x]))

# %%
df1
# Out:
#        label                            標題  \
# 0          1              田馥甄簽約何樂宣佈專巡送花籃力挺
# 1          1         梁靜茹新作好慘睽違年才回歸坦言對公司很抱歉
# 2          1        追星追起來登坂廣臣自告奮勇來台宣傳舉辦前夜祭
# 3          1         再會平成回顧輝煌歲月宇多田光締造的日音奇蹟
# 4          1          嘻哈狂粉注意紐約傳奇與世紀同台演唱會回顧
# 5          1            韓國嘻哈詩人時隔四年再度來台月日開唱
# 6          1    謝和弦讚他是頑童瘦子接班人高爾宣發新輯告白頑童的啟發
# 7          1        接棒蕭敬騰主持金曲獎史上最年輕主持人喊壓力大
# 8          1    盧廣仲攻蛋感動落幕小隊長告白懂得愛人才是大人暖哭萬人
# 9          1      動力火車開唱神翻唱周興哲怎麼了粉絲直呼耳朵懷孕了
# 10         1        合作釀災指控克里斯小子施暴過去遭反嗆一群魯蛇
# 11         1      藉自身經歷創作新歌反思網路世界的病症西洋速爆新歌
# 12         1          盧廣仲週年演唱會魚仔掀高潮自爆今日不洗澡
# 13         1      南優鉉植木日感性爆發邀粉絲將美好回憶一起種在心中
# 14         1  盧廣仲度攻蛋熱舞尬電音感謝神明保佑開唱前胃食道逆流險失聲
# 15         1       高爾宣穩坐冠軍寶座歌頌者擠進前五名華語新歌週榜
# 16         1             三強鼎立本週冠軍落誰家韓語新歌週榜
# 17         1     電音每週報樂迷敲破碗法國電音鬼才睽違年推出最新大碟
# 18         1  泰勒絲新歌邀迪斯可癟三主唱大玩復古風布蘭登不敢相信能合作
# 19         1        改寫歷史奪座拉丁告示牌音樂獎前輩後輩望塵莫及
# 20         1    阿信喊周董好帥五迷集體反告白蕭敬騰林俊傑網主唱心碎幫
# 21         1          高爾宣上節目露反差萌驚這不可能是同一個人
# 22         1                 新歌找來陷阱妹上演撲倒戲碼
# 23         1              嘻哈企劃齊聚全亞洲組嘻哈饒舌藝人
# 24         1           門票搶起來賴冠霖孝琳賣票日期都在這兩天
# 25         1    周興哲模仿周杰倫林俊傑自彈自唱粉絲哀求演唱會可以唱嗎
# 26         1     珍奶愛到唱成歌品冠新專輯收錄人氣手搖唱出吃貨幸福感
# 27         1   艾娃麥絲首訪亞洲預告新單曲將釋出等不及去台灣抱抱歌迷們
# 28         1                 要來台啦開唱日期選在這一天
# 29         1        歌迷敲碗成功新好男孩月開唱等經典神曲一次滿足
# ...      ...                           ...
# 46615      2    一周蘋選獨家揭光碟案內幕癌王秘兆大海內外新聞全台熱議
# 46616      5           英飛凌布局日本市場有成去年車用業務大增
# 46617      2                 月春遊嘉義市抽神秘百萬名車
# 12     [盧, 廣, 仲, 週, 年, 演, 唱, 會, 魚, 仔, 掀, 高, 潮, 自, 爆, ...
# 13     [南, 優, 鉉, 植, 木, 日, 感, 性, 爆, 發, 邀, 粉, 絲, 將, 美, ...
# 14     [盧, 廣, 仲, 度, 攻, 蛋, 熱, 舞, 尬, 電, 音, 感, 謝, 神, 明, ...
# 15     [高, 爾, 宣, 穩, 坐, 冠, 軍, 寶, 座, 歌, 頌, 者, 擠, 進, 前, ...
# 16     [三, 強, 鼎, 立, 本, 週, 冠, 軍, 落, 誰, 家, 韓, 語, 新, 歌, ...
# 17     [電, 音, 每, 週, 報, 樂, 迷, 敲, 破, 碗, 法, 國, 電, 音, 鬼, ...
# 18     [泰, 勒, 絲, 新, 歌, 邀, 迪, 斯, 可, 癟, 三, 主, 唱, 大, 玩, ...
# 19     [改, 寫, 歷, 史, 奪, 座, 拉, 丁, 告, 示, 牌, 音, 樂, 獎, 前, ...
# 20     [阿, 信, 喊, 周, 董, 好, 帥, 五, 迷, 集, 體, 反, 告, 白, 蕭, ...
# 21     [高, 爾, 宣, 上, 節, 目, 露, 反, 差, 萌, 驚, 這, 不, 可, 能, ...
# 22               [新, 歌, 找, 來, 陷, 阱, 妹, 上, 演, 撲, 倒, 戲, 碼]
# 23      [嘻, 哈, 企, 劃, 齊, 聚, 全, 亞, 洲, 組, 嘻, 哈, 饒, 舌, 藝, 人]
# 24     [門, 票, 搶, 起, 來, 賴, 冠, 霖, 孝, 琳, 賣, 票, 日, 期, 都, ...
# 25     [周, 興, 哲, 模, 仿, 周, 杰, 倫, 林, 俊, 傑, 自, 彈, 自, 唱, ...
# 26     [珍, 奶, 愛, 到, 唱, 成, 歌, 品, 冠, 新, 專, 輯, 收, 錄, 人, ...
# 27     [艾, 娃, 麥, 絲, 首, 訪, 亞, 洲, 預, 告, 新, 單, 曲, 將, 釋, ...
# 28               [要, 來, 台, 啦, 開, 唱, 日, 期, 選, 在, 這, 一, 天]
# 29     [歌, 迷, 敲, 碗, 成, 功, 新, 好, 男, 孩, 月, 開, 唱, 等, 經, ...
# ...                                                  ...
# 46615  [一, 周, 蘋, 選, 獨, 家, 揭, 光, 碟, 案, 內, 幕, 癌, 王, 秘, ...
# 46616  [英, 飛, 凌, 布, 局, 日, 本, 市, 場, 有, 成, 去, 年, 車, 用, ...
# 46617            [月, 春, 遊, 嘉, 義, 市, 抽, 神, 秘, 百, 萬, 名, 車]
# 46618  [北, 台, 灣, 今, 降, 溫, 涼, 爽, 舒, 適, 宜, 蘭, 發, 布, 大, ...
# 46619  [環, 球, 晶, 最, 美, 工, 廠, 在, 義, 大, 利, 一, 家, 四, 代, ...
# 46620         [平, 成, 日, 本, 人, 力, 短, 缺, 仰, 賴, 外, 籍, 勞, 工]
# 46621  [萬, 人, 明, 晨, 愛, 地, 球, 台, 北, 路, 跑, 用, 路, 人, 注, ...
# 46622  [世, 界, 企, 鵝, 蛙, 貘, 日, 台, 北, 動, 物, 園, 有, 日, 列, ...
# 46623  [小, 北, 極, 熊, 被, 困, 冰, 崖, 下, 熊, 媽, 媽, 攀, 峭, 壁, ...
# 46624  [看, 球, 要, 小, 心, 香, 香, 的, 玉, 米, 脆, 米, 差, 點, 被, ...
# 46625  [魔, 術, 強, 森, 閃, 辭, 原, 因, 曝, 光, 原, 來, 是, 總, 管, ...
# 46626  [英, 德, 之, 爭, 學, 者, 吳, 重, 禮, 不, 能, 只, 要, 對, 方, ...
# 46627  [季, 後, 賽, 富, 邦, 許, 晉, 哲, 不, 擔, 心, 生, 日, 魔, 咒, ...
# 46628  [運, 彩, 操, 盤, 手, 解, 盤, 大, 偉, 哥, 金, 塊, 抗, 壓, 性, ...
# 46629  [內, 村, 航, 平, 奧, 運, 全, 能, 連, 霸, 亮, 紅, 燈, 全, 日, ...
# 46630  [季, 後, 賽, 台, 啤, 璞, 園, 回, 到, 原, 點, 今, 第, 戰, 決, ...
# 46631  [蘋, 果, 人, 物, 先, 求, 帥, 再, 求, 快, 奧, 運, 馬, 拉, 松, ...
# 46632  [聯, 發, 科, 法, 說, 外, 資, 聚, 焦, 進, 度, 奈, 米, 製, 程, ...
# 46633  [報, 馬, 仔, 柯, 蕭, 主, 場, 就, 是, 王, 道, 奇, 不, 怕, 讓, ...
# 46634  [行, 競, 改, 裝, 經, 典, 雪, 佛, 蘭, 肌, 肉, 車, 變, 身, 純, ...
# 46635               [亮, 眼, 美, 股, 收, 紅, 納, 指, 再, 創, 新, 高]
# 46636  [月, 份, 家, 上, 市, 公, 司, 於, 證, 交, 所, 輪, 番, 舉, 辦, ...
# 46637  [平, 成, 日, 本, 人, 口, 負, 成, 長, 半, 數, 獨, 居, 銀, 髮, ...
# 46638  [中, 國, 地, 方, 官, 自, 製, 炸, 藥, 圖, 利, 住, 家, 爆, 炸, ...
# 46639  [平, 成, 笑, 傲, 職, 棒, 年, 鈴, 木, 一, 朗, 締, 造, 平, 成, ...
# 46640  [被, 導, 師, 要, 求, 論, 文, 重, 寫, 中, 國, 大, 專, 生, 崩, ...
# 46641  [奶, 茶, 妹, 老, 公, 被, 捕, 畫, 面, 曝, 光, 雙, 手, 反, 綁, ...
# 46642  [每, 月, 獲, 贈, 支, 菸, 菸, 草, 公, 司, 前, 員, 工, 怨, 害, ...
# 46643  [加, 拿, 大, 春, 汛, 洪, 災, 魁, 北, 克, 祭, 加, 幣, 萬, 元, ...
# 46644  [台, 灣, 男, 孩, 國, 民, 黨, 中, 央, 委, 員, 朗, 讀, 習, 近, ...
#
#                                               wordidlist
# 0      [650, 2200, 2088, 611, 254, 330, 159, 359, 146...
# 1      [1442, 1010, 1937, 8, 191, 104, 905, 1399, 754...
# 2      [660, 210, 660, 276, 44, 179, 1955, 801, 1893,...
# 3      [88, 10, 190, 29, 119, 751, 1384, 2122, 257, 5...
# 4      [1626, 517, 615, 393, 681, 182, 837, 254, 150,...
# 5      [84, 1, 1626, 517, 1347, 3, 97, 1430, 314, 7, ...
# 6      [512, 194, 1902, 758, 424, 74, 2078, 464, 1476...
# 7      [409, 881, 839, 908, 1106, 60, 274, 14, 250, 4...
# 8      [993, 801, 1354, 312, 526, 224, 57, 326, 556, ...
# 9      [57, 72, 118, 64, 17, 34, 202, 518, 34, 405, 8...
# 10     [131, 191, 1175, 770, 388, 645, 197, 279, 55, ...
# 46640  [83, 505, 270, 96, 406, 394, 45, 66, 930, 6, 1...
# 46641  [1091, 1327, 629, 173, 33, 83, 843, 675, 252, ...
# 46642  [651, 52, 201, 1716, 506, 1762, 1762, 1159, 33...
# 46643  [42, 447, 2, 717, 4395, 970, 770, 1646, 163, 1...
# 46644  [4, 61, 63, 387, 1, 18, 86, 6, 931, 185, 109, ...
#
# [46645 rows x 4 columns]

# %%
maxn = 0

for i in df1['wordidlist']:
    if len(i) > maxn:
        maxn = len(i)

print(maxn)
# Out:
# 37

# %%
maxlen = 25
df1['wordidlist'] = list(sequence.pad_sequences(df1['wordidlist'], maxlen=maxlen))

# %%
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation
import keras.optimizers
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing import sequence

# %%
df1['wordidlist'].dtype
# Out:
# dtype('O')

# %%
from sklearn.model_selection import train_test_split

# %%
X = np.array(list(df1['wordidlist']))
Y = np.array(list(df1['label']))

# %%
X[1]
# Out:
# array([   0,    0,    0,    0, 1442, 1010, 1937,    8,  191,  104,  905,
#        1399,  754,    7,  568,  119,  737, 1005,  533,   94,   33,  382,
#         755, 1082, 1317])

# %%
df1['wordidlist'][1].dtype
# Out:
# dtype('int32')

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state = 503)

# %%
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
#normalization
x_train = x_train/4645
x_test = x_test/4645

# %%
from keras.layers import Embedding, LSTM, Dropout

# %%
model = Sequential()
model.add(Embedding(len(word_dict)+1, 256))
model.add(LSTM(512))
model.add(Dropout(0.5))
model.add(Dense(y_train.shape[1]))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_10 (Embedding)     (None, None, 256)         1189376
# _________________________________________________________________
# lstm_12 (LSTM)               (None, 512)               1574912
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 4104
# _________________________________________________________________
# activation_8 (Activation)    (None, 8)                 0
# =================================================================
# Total params: 2,768,392
# Trainable params: 2,768,392
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train, y_train, batch_size=100, epochs=20)
# Out:
# Epoch 1/20
# 32651/32651 [==============================] - 46s 1ms/step - loss: 0.9558 - acc: 0.6586
# Epoch 2/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.5541 - acc: 0.8127
# Epoch 3/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.4711 - acc: 0.8375
# Epoch 4/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.4095 - acc: 0.8629
# Epoch 5/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.3668 - acc: 0.8748
# Epoch 6/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.3171 - acc: 0.8923
# Epoch 7/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.2813 - acc: 0.9048
# Epoch 8/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.2438 - acc: 0.9160
# Epoch 9/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.2166 - acc: 0.9247
# Epoch 10/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.1864 - acc: 0.9369
# Epoch 11/20
# 32651/32651 [==============================] - 44s 1ms/step - loss: 0.1597 - acc: 0.9455
# Epoch 12/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.1380 - acc: 0.9515
# Epoch 13/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.1245 - acc: 0.9568
# Epoch 14/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.1093 - acc: 0.9621
# Epoch 15/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.0996 - acc: 0.9655
# Epoch 16/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.0891 - acc: 0.9684
# Epoch 17/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.0793 - acc: 0.9715
# Epoch 18/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.0707 - acc: 0.9741
# Epoch 19/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.0634 - acc: 0.9776
# Epoch 20/20
# 32651/32651 [==============================] - 43s 1ms/step - loss: 0.0630 - acc: 0.9775

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 13994/13994 [==============================] - 8s 537us/step

# %%
print('loss:', score[0])
print('正確率', score[1])
# Out:
# loss: 1.40142691386
# 正確率 0.771044733466

# %%
from ipywidgets import interact_manual

# %%
predict = model.predict_classes(x_test)

# %%
def test(num):
    print(y_test[num])
    print('神經網路判斷為:', predict[num])

# %%
interact_manual(test, num=(0, len(y_test)-1))
# Out:
# A Jupyter Widget
# <function __main__.test>
