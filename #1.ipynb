# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 37, 25, 68])

# %%
plt.plot([1, 2, 3, 4], [1.2, 0, -5.6, 7])

# %%
X = [1, 2, 3, 4]
Y = [1.2, 0, -5.6, 7]
plt.plot(X, Y)

# %%
plt.scatter(X, Y)

# %%
np.random.rand(7)
# Out:
# array([0.58614239, 0.43979913, 0.39242722, 0.36302238, 0.2804286 ,
#        0.26727246, 0.06957855])

# %%
np.random.randn(7)
# Out:
# array([ 1.10067977,  0.9724403 ,  0.76958067,  0.31157576, -0.17065922,
#        -0.75862538, -0.96943059])

# %%
plt.plot(np.random.randn(100))

# %%
x = np.linspace(0, 10, 1000)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x, y)
